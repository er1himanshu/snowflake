# %% [markdown]
# <a href="https://colab.research.google.com/github/er1himanshu/snowflake/blob/main/snowflake.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
